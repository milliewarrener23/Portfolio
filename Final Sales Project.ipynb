# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
pd.read_csv('C:/Users/milli/OneDrive/Documents/Global Superstore.csv')

df = pd.read_csv('C:/Users/milli/OneDrive/Documents/Global Superstore.csv')

# %%
(df.head())
# Out:
#    Row ID                  Order ID  Order Date   Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954  11/11/2014  11/13/2014   First Class
# 1   26341    IN-2014-JR162107-41675    2/5/2014    2/7/2014  Second Class
# 2   25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014   First Class
# 3   13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014   First Class
# 4   47221   SG-2014-RH9495111-41948   11/5/2014   11/6/2014      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (1000, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          1000 non-null   int64
#  1   Order ID        1000 non-null   object
#  2   Order Date      1000 non-null   object
#  3   Ship Date       1000 non-null   object
#  4   Ship Mode       1000 non-null   object
#  5   Customer ID     1000 non-null   object
#  6   Customer Name   1000 non-null   object
#  7   Segment         1000 non-null   object
#  8   Postal Code     194 non-null    float64
#  9   City            1000 non-null   object
#  10  State           1000 non-null   object
#  11  Country         1000 non-null   object
#  12  Region          1000 non-null   object
#  13  Market          1000 non-null   object
#  14  Product ID      1000 non-null   object
#  15  Category        1000 non-null   object
#  16  Sub-Category    1000 non-null   object
# ...

# %%
df.describe()
# Out:
#              Row ID   Postal Code        Sales    Quantity     Discount  \
# count   1000.000000    194.000000  1000.000000  1000.00000  1000.000000
# mean   25079.328000  53966.170103  1710.971470     5.55800     0.092840
# std    12897.726632  33734.306466  1259.239238     2.71846     0.148666
# min       58.000000   2920.000000     1.910000     1.00000     0.000000
# 25%    15118.750000  19134.000000   826.907500     4.00000     0.000000
# 50%    25084.500000  60564.000000  1585.115000     5.00000     0.000000
# 75%    34524.000000  88187.500000  2477.812500     7.00000     0.150000
# max    51284.000000  98198.000000  9892.740000    14.00000     0.800000
#
#             Profit  Shipping Cost
# count  1000.000000    1000.000000
# mean    288.920440     272.384897
# std     574.504782     176.160716
# min   -3059.820000       1.070000
# 25%      10.037500     209.827500
# 50%     190.685000     258.897500
# 75%     518.872500     351.070250
# max    4946.370000     923.630000

# %%
print(df.isnull().sum())
df.dropna(inplace=True)
# Out:
# Row ID              0
# Order ID            0
# Order Date          0
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Postal Code       806
# City                0
# State               0
# Country             0
# Region              0
# Market              0
# Product ID          0
# Category            0
# Sub-Category        0
# Product Name        0
# Sales               0
# Quantity            0
# Discount            0
# Profit              0
# Shipping Cost       0
# Order Priority      0
# dtype: int64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
print(df)
print("\nData types:\n", df.dtypes)
# Out:
#      Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0     40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 8     40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 9     36258  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 10    36259  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 16    39519  CA-2012-AB10015140-40958 2012-02-19 2012-02-25  Standard Class
# ..      ...                       ...        ...        ...             ...
# 974   33951  CA-2015-AS10225140-42265 2015-09-18 2015-09-22    Second Class
# 976   33272  CA-2012-AS10225140-41199 2012-10-17 2012-10-19    Second Class
# 990   33274  CA-2012-AS10225140-41199 2012-10-17 2012-10-19    Second Class
# 992   33950  CA-2015-AS10225140-42265 2015-09-18 2015-09-22    Second Class
# 996   36249  CA-2015-AS10225140-42347 2015-12-09 2015-12-13    Second Class
#
# ...

# %%
#calculate total sales and total profit
total_sales = df['Sales'].sum()
total_profit = df['Profit'].sum()

print("Total Sales:", total_sales)
print("Total Profit:", total_profit)
# Out:
# Total Sales: 54535.08
# Total Profit: 12063.97

# %%
# Calculate total sales for each product
top_sales = df.groupby('Product Name')['Sales'].sum().reset_index()

# %%
# Sort by total sales in descending order to find top-selling products
top_sales_sorted = top_sales.sort_values(by='Sales', ascending=False)
print(top_sales_sorted)
# Out:
#                                           Product Name    Sales
# 63    GBC Ibimaster 500 Manual ProClick Binding System  9892.74
# 61           GBC DocuBind P400 Electric Binding System  4355.17
# 39                       Canon Image Class D660 Copier  2999.95
# 60           GBC DocuBind 300 Electric Binding Machine  2419.51
# 83                         Hon 5100 Series Wood Tables  2036.86
# ..                                                 ...      ...
# 109                                         Newell 323     3.36
# 7                            Acco Hanging Data Binders     3.05
# 115                        OIC #2 Pencils, Medium Soft     3.01
# 84   Hoover Replacement Belt for Commercial Guardsm...     2.22
# 92             Insertable Tab Indexes For Data Binders     1.91
#
# [178 rows x 2 columns]

# %%
# Get the top 10 best-selling products
top_10_sales = top_sales_sorted.head(10)
print(top_10_sales)
# Out:
#                                           Product Name    Sales
# 63    GBC Ibimaster 500 Manual ProClick Binding System  9892.74
# 61           GBC DocuBind P400 Electric Binding System  4355.17
# 39                       Canon Image Class D660 Copier  2999.95
# 60           GBC DocuBind 300 Electric Binding Machine  2419.51
# 83                         Hon 5100 Series Wood Tables  2036.86
# 29                         Bady BDG101FRU Card Printer  1439.98
# 16                     Avaya IP Phone 1140E VoIP phone  1394.95
# 71   Global Adaptabilites Bookcase, Cherry/Storm Gr...  1292.94
# 148                        Tennsco Single-Tier Lockers  1126.02
# 88           Ibico Ibimaster 300 Manual Binding System  1103.97

# %%
#group by country and calculate total sales
sales_by_state = df.groupby('State')['Sales'].sum().reset_index()
print(sales_by_state)
# Out:
#              State    Sales
# 0          Alabama  2216.80
# 1          Arizona  1244.61
# 2       California  4580.68
# 3         Colorado    46.69
# 4      Connecticut   916.59
# 5          Florida  1410.07
# 6          Georgia    12.84
# 7         Illinois   151.18
# 8          Indiana  1347.81
# 9         Kentucky  2971.43
# 10        Michigan  9892.74
# 11     Mississippi    86.45
# 12        Missouri  1207.76
# 13         Montana  4189.38
# 14          Nevada   196.45
# 15   New Hampshire    27.93
# 16        New York  8907.68
# 17  North Carolina   740.21
# 18            Ohio   121.33
# 19        Oklahoma   578.88
# 20          Oregon  1043.20
# 21    Pennsylvania  1112.93
# 22    Rhode Island  1169.98
# 23       Tennessee   522.70
# 24           Texas  4009.57
# 25            Utah  1457.82
# 26        Virginia   400.25
# 27      Washington  3971.12

# %%
# Sort by total sales in descending order
sales_by_state_sorted = sales_by_state.sort_values(by='Sales', ascending=False)
print(sales_by_state_sorted)
# Out:
#              State    Sales
# 10        Michigan  9892.74
# 16        New York  8907.68
# 2       California  4580.68
# 13         Montana  4189.38
# 24           Texas  4009.57
# 27      Washington  3971.12
# 9         Kentucky  2971.43
# 0          Alabama  2216.80
# 25            Utah  1457.82
# 5          Florida  1410.07
# 8          Indiana  1347.81
# 1          Arizona  1244.61
# 12        Missouri  1207.76
# 22    Rhode Island  1169.98
# 21    Pennsylvania  1112.93
# 20          Oregon  1043.20
# 4      Connecticut   916.59
# 17  North Carolina   740.21
# 19        Oklahoma   578.88
# 23       Tennessee   522.70
# 26        Virginia   400.25
# 14          Nevada   196.45
# 7         Illinois   151.18
# 18            Ohio   121.33
# 11     Mississippi    86.45
# 3         Colorado    46.69
# 15   New Hampshire    27.93
# 6          Georgia    12.84

# %%
# Calculate the correlation between Sales and Profit
correlation = df['Sales'].corr(df['Profit'])
print(f"Correlation between Sales and Profit: {correlation}")
# Out:
# Correlation between Sales and Profit: 0.9313979948257132

# %%
# Group by category and calculate total sales
sales_by_category = df.groupby('Category')['Sales'].sum().reset_index()
print(sales_by_category)
# Out:
#           Category     Sales
# 0        Furniture  13321.21
# 1  Office Supplies  28708.49
# 2       Technology  12505.38

# %%
# Sort by total sales (optional)
sales_by_category_sorted = sales_by_category.sort_values(by='Sales', ascending=False)
print(sales_by_category_sorted)
# Out:
#           Category     Sales
# 1  Office Supplies  28708.49
# 0        Furniture  13321.21
# 2       Technology  12505.38

# %%
# Bar chart for sales by product category
plt.bar(sales_by_category_sorted['Category'], sales_by_category_sorted['Sales'], color='skyblue')
plt.title('Sales by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Extract Year-Month for grouping
df['Year-Month'] = df['Order Date'].dt.to_period('M')

# Group by Year-Month and calculate total sales
monthly_sales = df.groupby('Year-Month')['Sales'].sum().reset_index()

# Convert 'Year-Month' back to datetime for plotting
monthly_sales['Year-Month'] = monthly_sales['Year-Month'].dt.to_timestamp()

# %%
# Plot the line graph
plt.plot(monthly_sales['Year-Month'], monthly_sales['Sales'], marker='o', color='blue')
plt.title('Monthly Sales Over Time')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
# Scatter plot
plt.scatter(df['Sales'], df['Profit'], color='blue', alpha=0.6, edgecolor='k')
plt.title('Scatter Plot of Sales vs. Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Pivot table for sales by region and category
heatmap_data = df.pivot_table(values='Sales', index='Region', columns='Category', aggfunc='sum', fill_value=0)

plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="YlGnBu", cbar=True)

plt.title('Sales by Region and Product Category')
plt.xlabel('Product Category')
plt.ylabel('Region')
plt.tight_layout()

plt.show()

# %%
# Resample data by month and sum sales
monthly_sales = df['Sales'].resample('ME').sum()

# Plot the time series of sales
monthly_sales.plot(figsize=(10, 6), title='Monthly Sales Over Time', marker='o')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.grid(True)
plt.tight_layout()
plt.show()
